# %%
import pandas as pd

# Hiển thị toàn bộ nội dung của mỗi cell
pd.set_option('display.max_colwidth', None)

# Hiển thị tất cả cột
pd.set_option('display.max_columns', None)

# Tăng chiều rộng hiển thị
pd.set_option('display.width', None)

# Hiển thị toàn bộ chiều rộng DataFrame
pd.set_option('display.expand_frame_repr', False)

# %%
df = pd.read_csv("crawl/data/topcv_person1.csv")
display(df.head(5))
# Out:
#                                                                                                                                                              url                                                                                                                   job_title                                                     company     location         salary  experience         education        level employment_type       industry                                                                                                                                                                                                  required_skills                                                                                                                    preferred_skills                                                                                                                                                                                                                                                      specialization                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            job_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   requirement
# 0                                                    https://www.topcv.vn/viec-lam/lap-trinh-vien-net-khong-yeu-cau-kinh-nghiem-thu-nhap-up-to-20-m/2051780.html                                                   Lập Trình Viên (.Net) - Không Yêu Cầu Kinh Nghiêm - Thu Nhập Up To 20 M++  Công ty cổ phần công nghệ và giải pháp trực tuyến Toàn Cầu       Hà Nội   8 - 20 triệu       2 năm   Đại Học trở lên    Nhân viên  Toàn thời gian  IT - Phần mềm                                                                                                                                                                                                               []                                                                                                                                  []                                                                                                                                                                                                       ['2 năm kinh nghiệm', 'Đại Học trở lên', 'Software Engineer']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   - Tham gia các dự án phần mềm của Công ty. - Xây dựng kế hoạch và quản lý tiến độ lập trình theo kế hoạch. - Thiết kế module chi tiết. - Tham gia vào các dự án phát triển sản phẩm của Công ty trên nền tảng ASP.NET hoặc .NET core. - Lập trình và tích hợp (Front-end và back-end). - Xem xét code kiểm thử và thử nghiệm. - Viết tài liệu mô tả chức năng phần mềm. - Phối hợp với các bộ phận để phát hiện và xử lý lỗi hiệu quả. - Bảo trì và hỗ trợ các vấn đề liên quan đến lập trình. - Thực hiện các công việc khác theo sự phân công của lãnh đạo. - Thời gian làm việc: 8h-17h00 (nghỉ chủ nhật, chiều thứ 7 và các ngày lễ)                                                                                                                                                                                                                                                                                                                         - Tốt nghiệp Đại học, Cao đẳng, trung tâm đào tạo chuyên ngành CNTT. - Có hiểu biết về ASP.NET, OOP, RESFULL, Design Patterns. - Có hiểu biết về lập trình Backend – Frontend, Javascript, HTML, CSS, HTTP. - Nắm vững kiến thức cơ bản về lập trình SQL và hiểu biết về SQL Server hoặc Oracle Database. - Có kinh nghiệm trong phát triển ứng dụng Web. - Có tư duy logic tốt, có tinh thần trách nhiệm, ham học hỏi và nhiệt tình với công việc. - Có khả năng đọc hiểu tài liệu tiếng Anh. - Có kỹ năng làm việc độc lập và phối hợp theo nhóm. - Hiểu biết về lập trình mobile là một lợi thế. - Công ty nhận đào tạo sinh viên mới ra trường có kiến thức và ham muốn trở thành lập trình viên.
# 1                                                                          https://www.topcv.vn/viec-lam/mobile-app-engineer-ios-android-ai-glasses/2099156.html                                                                          Mobile App Engineer ( IOS / Android ) – AI Glasses                                         CÔNG TY TNHH VEANIX       Hà Nội     Thoả thuận  Trên 5 năm   Đại Học trở lên  Trưởng nhóm  Toàn thời gian  IT - Phần mềm                                                                                                                                ['Swift (ios) Hoặc Kotlin Java (android)', 'Lập Trình Giao Diện Người Dùng (ui)']  ['Kiến Thức Về Ai Machine Learning', 'Kinh Nghiệm Làm Việc Với Các Thư Viện Ai Ml Trên Di Động (ví Dụ: Tensorflow Lite, Core Ml)']                                                                                                                         ['Trên 5 năm kinh nghiệm', 'Đại Học trở lên', 'Tuổi 28 - 35', 'Nam', 'Tiếng Anh Giao tiếp thành thạo', 'Mobile Developer', 'IT - Phần mềm']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Phát triển ứng dụng mobile (iOS / Android) cho sản phẩm AI Glasses Xây dựng các tính năng chính: Kết nối thiết bị qua Bluetooth (BLE) Pairing, quản lý trạng thái thiết bị Streaming dữ liệu (voice / image) từ kính → app / cloud Tích hợp với hệ thống AI: Hiển thị phản hồi từ AI Assistant Giao tiếp với backend (API, realtime) Thiết kế và tối ưu trải nghiệm người dùng (UX) cho thiết bị wearable Tối ưu hiệu năng: Realtime processing Battery usage Phối hợp với: Hardware team (kính) AI / Backend team Tham gia phát triển sản phẩm từ prototype → production                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Có kinh nghiệm phát triển mobile: iOS (Swift) hoặc Android (Kotlin) Hiểu về: REST API, networking State management Có kinh nghiệm làm việc với: Bluetooth (BLE) hoặc device connection là lợi thế lớn Có khả năng debug và tối ưu hiệu năng ứng dụng Có tư duy sản phẩm, không chỉ làm UI
# 2  https://www.topcv.vn/viec-lam/graphic-visual-designer-thoi-trang-nu-cao-cap-quan-2-thu-nhap-tot-nhieu-khong-gian-sang-tao-ket-hop-ai-di-lam-ngay/2093786.html  Graphic /Visual Designer , Thời Trang Nữ Cao Cấp, Quận 2, Thu Nhập Tốt, Nhiều Không Gian Sáng Tạo, Kết Hợp AI, Đi Làm Ngay                        Thương hiệu thời trang Oceana London  Hồ Chí Minh     Thoả thuận       1 năm  Cao Đẳng trở lên    Nhân viên  Toàn thời gian     Thời trang  ['Kỹ năng giao tiếp', 'Thiết kế đồ họa', 'Thiết Kế Hình Ảnh', 'Kỹ năng làm việc nhóm', 'Sáng tạo', 'Hiểu Biết Về Màu Sắc', 'Sử Dụng Phần Mềm Thiết Kế (adobe Photoshop, Illustrator, Indesign)', 'Thẩm Mỹ Tốt']                            ['Hiểu Biết Về Ngành Thời Trang Nữ Cao Cấp', 'Sử Dụng Ai Trong Thiết Kế (midjourney, Stable Diffusion)']  ['1 năm kinh nghiệm', 'Cao Đẳng trở lên', 'Tiếng Anh Đọc hiểu', 'Tiếng Anh Giao tiếp cơ bản', 'Bảo hiểm xã hội', 'Team building', 'Du lịch hàng năm', 'Thiết kế đồ họa (Graphic Design)', 'May mặc / Thời trang', 'Marketing / Quảng cáo', 'Thiết kế / Kiến trúc']                                                                                                                                                                                                                                                                         Oceana & Baga là thương hiệu thời trang đang phát triển mạnh với phong cách thanh lịch và tinh tế. Năm 2026, chúng tôi sẽ triển khai những dự án branding thú vị và đang tìm kiếm một bạn Junior Graphic Designer để cùng team Creative tạo ra những visual đẹp và hiệu quả. MÔ TẢ CÔNG VIỆC Thiết kế graphic cho các chiến dịch marketing: khuyến mãi, nội dung social media, banner và tài liệu quảng cáo Phối hợp với team Creative xây dựng visual cho bộ sưu tập mới, bao gồm banner, poster, key visual và các yếu tố đồ họa hỗ trợ trên các kênh social Hỗ trợ chuẩn bị concept, đạo cụ và bối cảnh cho các buổi photoshoot lookbook & campaign Học hỏi và sử dụng các công cụ AI để hỗ trợ thiết kế, tối ưu quy trình làm việc (công ty sẽ đào tạo thêm) Cập nhật xu hướng thiết kế và hình ảnh thời trang trên Pinterest, Behance, TikTok                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Quan Trọng: Có Portfolio thể hiện phong cách cá nhân phù hợp với brand thời trang (có thể là đồ án, dự án cá nhân) Tốt nghiệp chuyên ngành Thiết kế Đồ họa, Thiết kế Thời trang hoặc ngành liên quan Yêu thích thời trang và có gu thẩm mỹ tốt Thành thạo Adobe Photoshop và Illustrator Biết sử dụng công cụ AI là một điểm cộng lớn Chủ động học hỏi, thường xuyên cập nhật xu hướng thiết kế Khả năng làm việc nhóm và chịu áp lực deadline
# 3                                                                                               https://www.topcv.vn/viec-lam/backend-lead-engineer/2050356.html                                                                                                       Backend Lead Engineer                          CÔNG TY TNHH LEVER SPHERE VIỆT NAM       Hà Nội  50 - 70 triệu       3 năm   Đại Học trở lên  Trưởng nhóm  Toàn thời gian           Luật                                                                                                                                                    ['Thiết Kế Hệ Thống', 'System Design', 'Backend Development']                                                                                     ['Mysql/Postgresql', 'Php/Python/Java/Node.js']                                                                                       ['3 năm kinh nghiệm', 'Đại Học trở lên', 'Tuổi 25 - 40', 'Bảo hiểm xã hội', 'Bảo hiểm sức khỏe', 'Team building', 'Backend Developer', 'IT - Phần mềm', 'Thương mại điện tử']  KEY OUTCOMES: NHỮNG KẾT QUẢ CỤ THỂ CẦN ĐẠT TRONG 6 - 18 THÁNG Làm chủ và tối ưu hóa thành công các ETL/ELT jobs và event pipelines để dữ liệu từ TikTok Shop, Shopify, Facebook đổ về hệ thống luôn chính xác và thời gian thực (Real-time). Thiết kế và chuẩn hóa lại Schema Data tối ưu cho việc truy vấn báo cáo hiệu suất (Product performance, Ads metrics). Dẫn dắt việc nâng cấp kiến trúc (Refactor/Microservices) giúp hệ thống chịu tải tốt hơn khi quy mô SKU và đơn hàng tăng trưởng đột biến. Xây dựng đội ngũ backend kế thừa thông qua việc thiết lập coding guidelines và mentoring. SUCCESS INDICATORS: CHỈ SỐ ĐO LƯỜNG THÀNH CÔNG Data Accuracy & Integrity: Tỷ lệ sai lệch dữ liệu giữa các nền tảng tích hợp (TikTok/Shopify) và hệ thống nội bộ < 1%. System Performance: Giảm thời gian phản hồi API và tối ưu hóa query plan cho các tập dữ liệu lớn (Heavy Data). Time-to-Market: Tốc độ chuyển hóa từ yêu cầu kinh doanh sang giải pháp kỹ thuật thực tế mà không cần qua trung gian PM. Engineering Quality: Tỷ lệ bug nghiêm trọng phát sinh sau release và hiệu quả của các buổi Code Review.  NĂNG LỰC & KỸ NĂNG CẦN CÓ Expert Backend Stack: Thành thạo PHP/Laravel (bắt buộc) và có tư duy tốt về MySQL/Postgres (JSONB, Indexing, Transaction design). System Thinking: Khả năng nhìn bức tranh tổng thể để tìm "điểm gãy" của hệ thống trên nhiều phương diện: vận hành, logistics, marketing. Problem Solving: Tự bóc tách logic kinh doanh thành phương án kỹ thuật khả thi, biết cân bằng giữa tốc độ triển khai và rủi ro kỹ thuật (Trade-off). Data Engineering: Kinh nghiệm xây dựng Pipeline xử lý dữ liệu lớn và các hệ thống bất đồng bộ (Asynchronous pipeline, Queue/Worker). CHALLENGES: NHỮNG THÁCH THỨC LỚN CỦA VỊ TRÍ Complexity & Ambiguity: Phải xử lý vấn đề ngay cả khi yêu cầu từ phía Business chưa rõ ràng hoặc liên tục thay đổi theo thị trường eCommerce. Data Volume: Giải quyết bài toán hiệu năng khi đối mặt với lượng dữ liệu "khủng" từ các nền tảng quảng cáo và vận hành. Integration Maze: Duy trì sự ổn định của hệ thống khi tích hợp với nhiều API bên thứ ba có độ phức tạp cao.
# 4                          https://www.topcv.vn/viec-lam/nhan-vien-kinh-doanh-tu-van-ban-hang-sales-thu-nhap-tu-10-50-trieu-hoa-hong-khong-gioi-han/2092356.html                          Nhân Viên Kinh Doanh / Tư Vấn Bán Hàng / Sales Thu Nhập Từ 10 - 50 Triệu + Hoa Hồng Không Giới Hạn                         CÔNG TY CỔ PHẦN RAPIDA TECHNOLOGIES       Hà Nội  15 - 50 triệu       1 năm  Cao Đẳng trở lên    Nhân viên  Toàn thời gian  IT - Phần mềm                                                                                                                                                                                                               []                                                                                                                                  []                                                                                                                                                                                      ['1 năm kinh nghiệm', 'Cao Đẳng trở lên', 'Kinh doanh phần mềm', 'B2B', 'B2C']                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Tìm kiếm, liên hệ và tư vấn khách hàng sử dụng phần mềm quản lý bán hàng ShopQR Demo sản phẩm online (TeamViewer/Google Meet/Zalo) hoặc trực tiếp tại cửa hàng Phân tích nhu cầu và đề xuất giải pháp phù hợp với từng mô hình kinh doanh Báo giá, đàm phán và chốt hợp đồng Hỗ trợ triển khai ban đầu và hướng dẫn khách hàng sử dụng Chăm sóc khách hàng sau bán, khai thác thêm nhu cầu (upsell, referral)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Có từ 1 năm kinh nghiệm Sales / Telesales / Kinh doanh Tốt nghiệp Trung cấp/Cao đẳng/Đại học Giao tiếp tốt, chủ động, có khả năng thuyết phục Sử dụng cơ bản Word, Excel, Internet, Facebook, Zalo Có laptop và phương tiện di chuyển Ưu tiên: Kinh nghiệm bán phần mềm, SaaS, POS hoặc ngành F&B/bán lẻ Có kinh nghiệm đi thị trường hoặc chốt deal trực tiếp
